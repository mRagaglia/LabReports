# %%
# plots will be shown inline 
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
import pandas as pd
import math
from numpy import sqrt,floor
import scipy as sp
import random
from scipy import stats
# libreria locale
import my_lib_santanastasio as my 
import numpy.fft 
from astropy.io import fits
from astropy.utils.data import download_file

##NOTA IMPORTANTE: se cambi qualcosa in my_lib_santanastasio 
# devi fare Kernel --> Restart prima di rigirare il codice
# altrimenti i cambiamenti non saranno applicati.

# set global random seed
random_Gseed = 1112
np.random.seed(random_Gseed)

# %% [markdown]
# # BLU

# %%
mediab = fits.getdata('bnobias.fit')

# %%
mediab = fits.getdata('media_b.fit')

# %%
print(mediab[0])
# Out:
# [[ 580.3266 7630.1123 7630.1123 ... 7970.2363 8011.998  8011.998 ]
#  [ 580.3266 7831.11   7831.11   ... 8168.8696 8234.107  8234.107 ]
#  [ 580.3266 8032.1074 8032.1074 ... 8367.503  8456.216  8456.216 ]
#  ...
#  [ 580.3266 7471.297  7471.297  ... 7914.427  7936.2188 7936.2188]
#  [ 580.3266 7495.0825 7495.0825 ... 7965.4443 7992.632  7992.632 ]
#  [ 580.3266 7495.0825 7495.0825 ... 7965.4443 7992.632  7992.632 ]]

# %%
print(type(mediab.flat))
print(mediab.shape)
# Out:
# <class 'numpy.flatiter'>
# (3, 1536, 1024)

# %%
mediab = fits.open('media_b.fit')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-e61e6df3c71f> in <module>
# ----> 1 print(mediab[0])
#
# TypeError: 'PrimaryHDU' object is not subscriptable

# %%
mediab.info()
# Out:
# Filename: media_b.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      43   (1024, 1536, 3)   float32

# %%
mediab = fits.getdata('bnobias.fit')

# %%
print(type(mediab.flat))
print(mediab.shape)
# Out:
# <class 'numpy.flatiter'>
# (1536, 1024)

# %%
NBINS = 1000
histogram = plt.hist(mediab.flat, NBINS)
#plt.xlim(6000,10000)

# %%
from matplotlib.colors import LogNorm
plt.imshow(mediab, vmin=5000, vmax=7000)
#plt.colorbar()


# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[5000,6000,7000])
cbar.ax.set_yticklabels(['5,000','6,000','7,000'])
# Out:
# [Text(1, 5000, '5,000'), Text(1, 6000, '6,000'), Text(1, 7000, '7,000')]

# %% [markdown]
# # IR

# %%
mediab = fits.getdata('irnobias.fit')

# %%
print(type(mediab.flat))
print(mediab.shape)
# Out:
# <class 'numpy.flatiter'>
# (1536, 1024)

# %%
NBINS = 1000
histogram = plt.hist(mediab.flat, NBINS)
plt.xlim(10000,16000)
# Out:
# (10000.0, 16000.0)

# %%
from matplotlib.colors import LogNorm
plt.imshow(mediab, vmin=11000, vmax=15500)
#plt.colorbar()


# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[11000,13000,15500])
#cbar.ax.set_yticklabels(['5,000','6,000','7,000'])

# %% [markdown]
# # VISIBILE

# %%
mediab = fits.getdata('vnobias.fit')

# %%
histogram=plt.hist(mediab.flat, NBINS)

# %%
from matplotlib.colors import LogNorm
plt.imshow(mediab, vmin=4500, vmax=6500)
#plt.colorbar()


# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[4500,5500,6500])
#cbar.ax.set_yticklabels(['5,000','6,000','7,000'])

# %% [markdown]
# # ROSSO

# %%
mediab = fits.getdata('rnobias.fit')

# %%
histogram=plt.hist(mediab.flat, NBINS)

# %%
from matplotlib.colors import LogNorm
plt.imshow(mediab, vmin=26000, vmax=33000)
#plt.colorbar()


# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[26000,29000,33000])
#cbar.ax.set_yticklabels(['5,000','6,000','7,000'])

# %% [markdown]
# # GRISM

# %%
mediab = fits.getdata('gnobias.fit')
histogram=plt.hist(mediab.flat, NBINS)

# %%
from matplotlib.colors import LogNorm
plt.imshow(mediab, vmin=5000, vmax=21500)
#plt.colorbar()


# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[5000,11000,16000,21500])
#cbar.ax.set_yticklabels(['5,000','6,000','7,000'])
